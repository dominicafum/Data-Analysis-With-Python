# %%
#import packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import geopandas as gpd

# %%
#Read csv file into dataframe
df = pd.read_csv('/content/Annual_Surface_Temperature_Change.csv')

# %%
#Display first 5 rows
df.head(5)
# Out:
#    ObjectId                       Country ISO2 ISO3  \
# 0         1  Afghanistan, Islamic Rep. of   AF  AFG
# 1         2                       Albania   AL  ALB
# 2         3                       Algeria   DZ  DZA
# 3         4                American Samoa   AS  ASM
# 4         5      Andorra, Principality of   AD  AND
#
#                                            Indicator            Unit  \
# 0  Temperature change with respect to a baseline ...  Degree Celsius
# 1  Temperature change with respect to a baseline ...  Degree Celsius
# 2  Temperature change with respect to a baseline ...  Degree Celsius
# 3  Temperature change with respect to a baseline ...  Degree Celsius
# 4  Temperature change with respect to a baseline ...  Degree Celsius
#
#                                               Source CTS_Code  \
# 0  Food and Agriculture Organization of the Unite...     ECCS
# 1  Food and Agriculture Organization of the Unite...     ECCS
# ...

# %%
df.describe()
# Out:
#          ObjectId       F1961       F1962       F1963       F1964       F1965  \
# count  225.000000  188.000000  189.000000  188.000000  188.000000  188.000000
# mean   113.000000    0.163053   -0.013476   -0.006043   -0.070059   -0.247027
# std     65.096083    0.405080    0.341812    0.387348    0.309305    0.270734
# min      1.000000   -0.694000   -0.908000   -1.270000   -0.877000   -1.064000
# 25%     57.000000   -0.097000   -0.164000   -0.205500   -0.236500   -0.392500
# 50%    113.000000    0.064500   -0.056000   -0.003000   -0.056000   -0.230500
# 75%    169.000000    0.318500    0.114000    0.230500    0.132500   -0.091500
# max    225.000000    1.892000    0.998000    1.202000    1.097000    0.857000
#
#             F1966       F1967       F1968       F1969  ...       F2013  \
# count  192.000000  191.000000  191.000000  190.000000  ...  216.000000
# mean     0.105505   -0.110832   -0.199110    0.157942  ...    0.931199
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      ObjectId                       Country ISO2 ISO3  \
# 0           1  Afghanistan, Islamic Rep. of   AF  AFG
# 1           2                       Albania   AL  ALB
# 2           3                       Algeria   DZ  DZA
# 3           4                American Samoa   AS  ASM
# 4           5      Andorra, Principality of   AD  AND
# ..        ...                           ...  ...  ...
# 220       221                Western Sahara   EH  ESH
# 221       222                         World  NaN  WLD
# 222       223                Yemen, Rep. of   YE  YEM
# 223       224                        Zambia   ZM  ZMB
# 224       225                      Zimbabwe   ZW  ZWE
#
#                                              Indicator            Unit  \
# 0    Temperature change with respect to a baseline ...  Degree Celsius
# 1    Temperature change with respect to a baseline ...  Degree Celsius
# ...

# %%
df.isnull().sum()
# Out:
# ObjectId      0
# Country       0
# ISO2          2
# ISO3          0
# Indicator     0
#              ..
# F2018        12
# F2019        12
# F2020        13
# F2021        12
# F2022        12
# Length: 72, dtype: int64

# %%
df.fillna(0, inplace=True)

# %%
df = df.drop(columns=['ISO2', 'Indicator', 'Source', 'CTS_Code', 'CTS_Name', 'CTS_Full_Descriptor'], errors='ignore')

# %%
df.head()
# Out:
#    ObjectId                       Country ISO3            Unit  F1961  F1962  \
# 0         1  Afghanistan, Islamic Rep. of  AFG  Degree Celsius -0.113 -0.164
# 1         2                       Albania  ALB  Degree Celsius  0.627  0.326
# 2         3                       Algeria  DZA  Degree Celsius  0.164  0.114
# 3         4                American Samoa  ASM  Degree Celsius  0.079 -0.042
# 4         5      Andorra, Principality of  AND  Degree Celsius  0.736  0.112
#
#    F1963  F1964  F1965  F1966  ...  F2013  F2014  F2015  F2016  F2017  F2018  \
# 0  0.847 -0.764 -0.244  0.226  ...  1.281  0.456  1.093  1.555  1.540  1.544
# 1  0.075 -0.166 -0.388  0.559  ...  1.333  1.198  1.569  1.464  1.121  2.028
# 2  0.077  0.250 -0.100  0.433  ...  1.192  1.690  1.121  1.757  1.512  1.210
# 3  0.169 -0.140 -0.562  0.181  ...  1.257  1.170  1.009  1.539  1.435  1.189
# 4 -0.752  0.308 -0.490  0.415  ...  0.831  1.946  1.690  1.990  1.925  1.919
#
#    F2019  F2020  F2021  F2022
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Country'].count()
# Out:
# 225

# %%
df['Country'].nunique()
# Out:
# 225

# %%
df = df.rename(columns={
    'F1961': '1961',
    'F1962': '1962',
    'F1963': '1963',
    'F1964': '1964',
    'F1965': '1965',
    'F1966': '1966',
    'F1967': '1967',
    'F1968': '1968',
    'F1969': '1969',
    'F1970': '1970',
    'F1971': '1971',
    'F1972': '1972',
    'F1973': '1973',
    'F1974': '1974',
    'F1975': '1975',
    'F1976': '1976',
    'F1977': '1977',
    'F1978': '1978',
    'F1979': '1979',
    'F1980': '1980',
    'F1981': '1981',
    'F1982': '1982',
    'F1983': '1983',
    'F1984': '1984',
    'F1985': '1985',
    'F1986': '1986',
    'F1987': '1987',
    'F1988': '1988',
    'F1989': '1989',
    'F1990': '1990',
    'F1991': '1991',
    'F1992': '1992',
    'F1993': '1993',
    'F1994': '1994',
    'F1995': '1995',
    'F1996': '1996',
    'F1997': '1997',
    'F1998': '1998',
    'F1999': '1999',
    'F2000': '2000',
    'F2001': '2001',
    'F2002': '2002',
    'F2003': '2003',
    'F2004': '2004',
    'F2005': '2005',
    'F2006': '2006',
    'F2007': '2007',
    'F2008': '2008',
    'F2009': '2009',
    'F2010': '2010',
    'F2011': '2011',
    'F2012': '2012',
    'F2013': '2013',
    'F2014': '2014',
    'F2015': '2015',
    'F2016': '2016',
    'F2017': '2017',
    'F2018': '2018',
    'F2019': '2019',
    'F2020': '2020',
    'F2021': '2021',
    'F2022': '2022'
})

# %%
df.head()
# Out:
#    ObjectId                       Country ISO3            Unit   1961   1962  \
# 0         1  Afghanistan, Islamic Rep. of  AFG  Degree Celsius -0.113 -0.164
# 1         2                       Albania  ALB  Degree Celsius  0.627  0.326
# 2         3                       Algeria  DZA  Degree Celsius  0.164  0.114
# 3         4                American Samoa  ASM  Degree Celsius  0.079 -0.042
# 4         5      Andorra, Principality of  AND  Degree Celsius  0.736  0.112
#
#     1963   1964   1965   1966  ...   2013   2014   2015   2016   2017   2018  \
# 0  0.847 -0.764 -0.244  0.226  ...  1.281  0.456  1.093  1.555  1.540  1.544
# 1  0.075 -0.166 -0.388  0.559  ...  1.333  1.198  1.569  1.464  1.121  2.028
# 2  0.077  0.250 -0.100  0.433  ...  1.192  1.690  1.121  1.757  1.512  1.210
# 3  0.169 -0.140 -0.562  0.181  ...  1.257  1.170  1.009  1.539  1.435  1.189
# 4 -0.752  0.308 -0.490  0.415  ...  0.831  1.946  1.690  1.990  1.925  1.919
#
#     2019   2020   2021   2022
# ...

# %%
  df = df.rename(columns={'ObjectId': 'ID'})

# %%
df.head()
# Out:
#    ID                       Country ISO3            Unit   1961   1962   1963  \
# 0   1  Afghanistan, Islamic Rep. of  AFG  Degree Celsius -0.113 -0.164  0.847
# 1   2                       Albania  ALB  Degree Celsius  0.627  0.326  0.075
# 2   3                       Algeria  DZA  Degree Celsius  0.164  0.114  0.077
# 3   4                American Samoa  ASM  Degree Celsius  0.079 -0.042  0.169
# 4   5      Andorra, Principality of  AND  Degree Celsius  0.736  0.112 -0.752
#
#     1964   1965   1966  ...   2013   2014   2015   2016   2017   2018   2019  \
# 0 -0.764 -0.244  0.226  ...  1.281  0.456  1.093  1.555  1.540  1.544  0.910
# 1 -0.166 -0.388  0.559  ...  1.333  1.198  1.569  1.464  1.121  2.028  1.675
# 2  0.250 -0.100  0.433  ...  1.192  1.690  1.121  1.757  1.512  1.210  1.115
# 3 -0.140 -0.562  0.181  ...  1.257  1.170  1.009  1.539  1.435  1.189  1.539
# 4  0.308 -0.490  0.415  ...  0.831  1.946  1.690  1.990  1.925  1.919  1.964
#
#     2020   2021   2022
# ...

# %%
ghana_temp = df[df['Country'] == 'Ghana']

# %%
ghana_temp.head()
# Out:
#     ID Country ISO3            Unit  1961   1962   1963   1964  1965   1966  \
# 75  76   Ghana  GHA  Degree Celsius -0.07 -0.154  0.141 -0.233 -0.17  0.068
#
#     ...   2013   2014   2015   2016   2017   2018  2019   2020   2021   2022
# 75  ...  0.841  0.887  1.132  1.217  1.292  1.081  1.32  1.284  1.494  0.996
#
# [1 rows x 66 columns]

# %%
print(df.dtypes)
# Out:
# ID           int64
# Country     object
# ISO3        object
# Unit        object
# 1961       float64
#             ...
# 2018       float64
# 2019       float64
# 2020       float64
# 2021       float64
# 2022       float64
# Length: 66, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' contains the dataset
# Select Ghana’s temperature values (excluding metadata columns)
ghana_temp = df[df['Country'] == 'Ghana'].iloc[:, 4:]  # Skipping first 4 columns (ID, Country, ISO3, Unit)

# Convert year column names to integers (optional, if they are strings)
ghana_temp.columns = ghana_temp.columns.astype(int)

# Transpose to get years as the X-axis
ghana_temp = ghana_temp.T

# Rename the column for clarity
ghana_temp.columns = ['Temperature']

# Plot the temperature trend
plt.figure(figsize=(12, 6))
plt.plot(ghana_temp.index, ghana_temp['Temperature'], linestyle='-', color ='r')

# Formatting the plot
plt.xlabel('Year')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Trend for Ghana (1961–2022)')
plt.grid(True)
plt.xticks(rotation=45)  # Rotate year labels for better visibility
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Extract Ghana’s temperature values (Skipping first 4 columns: ID, Country, ISO3, Unit)
ghana_temp = df[df['Country'] == 'Ghana'].iloc[:, 4:]

# Convert column names (years) to integers
ghana_temp.columns = ghana_temp.columns.astype(int)

# Transpose the dataset for easier plotting
ghana_temp = ghana_temp.T
ghana_temp.columns = ['Temperature']

# Split the dataset into Pre-COVID (1961–2019) and Post-COVID (2020–2022)
pre_covid = ghana_temp.loc[1961:2019]
post_covid = ghana_temp.loc[2020:2022]

# Plot the trends
plt.figure(figsize=(12, 6))
plt.plot(pre_covid.index, pre_covid['Temperature'], marker='o', linestyle='-', label='Pre-COVID (1961–2019)', color='blue')
plt.plot(post_covid.index, post_covid['Temperature'], marker='o', linestyle='-', label='Post-COVID (2020–2022)', color='red')

# Formatting the plot
plt.xlabel('Year')
plt.ylabel('Temperature (°C)')
plt.title('Pre vs. Post-COVID Temperature Trends in Ghana')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()

# Show the plot
plt.show()

# %%
# Extract Ghana’s temperature data (Skipping metadata columns)
ghana_temp = df[df['Country'] == 'Ghana'].iloc[:, 4:]

# Convert column names (years) to integers
ghana_temp.columns = ghana_temp.columns.astype(int)

# Transpose for easier manipulation
ghana_temp = ghana_temp.T
ghana_temp.columns = ['Temperature']

# Find the year with the highest temperature
max_year = ghana_temp['Temperature'].idxmax()
max_temp = ghana_temp['Temperature'].max()

# Print results
print(f"The highest recorded temperature in Ghana was {max_temp:.2f}°C in the year {max_year}.")
# Out:
# The highest recorded temperature in Ghana was 1.49°C in the year 2021.

# %%
# Extract Ghana’s temperature data (Skipping metadata columns)
ghana_temp = df[df['Country'] == 'Ghana'].iloc[:, 4:]

# Convert column names (years) to integers
ghana_temp.columns = ghana_temp.columns.astype(int)

# Transpose for easier manipulation
ghana_temp = ghana_temp.T
ghana_temp.columns = ['Temperature']

# Find the year with the lowest temperature
min_year = ghana_temp['Temperature'].idxmin()
min_temp = ghana_temp['Temperature'].min()

# Print results
print(f"The lowest recorded temperature in Ghana was {min_temp:.2f}°C in the year {min_year}.")
# Out:
# The lowest recorded temperature in Ghana was -0.35°C in the year 1976.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Extract temperature data for Ghana and Nigeria
ghana_temp = df[df['Country'] == 'Ghana'].iloc[:, 4:]
nigeria_temp = df[df['Country'] == 'Nigeria'].iloc[:, 4:]

# Convert column names (years) to integers
ghana_temp.columns = ghana_temp.columns.astype(int)
nigeria_temp.columns = nigeria_temp.columns.astype(int)

# Transpose the datasets
ghana_temp = ghana_temp.T
nigeria_temp = nigeria_temp.T

# Rename columns
ghana_temp.columns = ['Ghana']
nigeria_temp.columns = ['Nigeria']

# Combine both into one DataFrame for comparison
temp_comparison = pd.concat([ghana_temp, nigeria_temp], axis=1)

# Plot the temperature trends
plt.figure(figsize=(12, 6))
plt.plot(temp_comparison.index, temp_comparison['Ghana'], linestyle='-', label='Ghana', color='blue')
plt.plot(temp_comparison.index, temp_comparison['Nigeria'], linestyle='-', label='Nigeria', color='green')

# Formatting the plot
plt.xlabel('Year')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Trends: Ghana vs. Nigeria')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Extract temperature data for Ghana and Nigeria
ghana_temp = df[df['Country'] == 'Ghana'].iloc[:, 4:]
nigeria_temp = df[df['Country'] == 'Nigeria'].iloc[:, 4:]

# Convert column names (years) to integers
ghana_temp.columns = ghana_temp.columns.astype(int)
nigeria_temp.columns = nigeria_temp.columns.astype(int)

# Transpose the datasets
ghana_temp = ghana_temp.T
nigeria_temp = nigeria_temp.T

# Rename columns
ghana_temp.columns = ['Ghana']
nigeria_temp.columns = ['Nigeria']

# Set up the figure and axes for small multiple plots
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10, 8), sharex=True, sharey=True)

# Ghana Temperature Plot
axes[0].plot(ghana_temp.index, ghana_temp['Ghana'], linestyle='-', color='blue')
axes[0].set_title('Temperature Trend in Ghana')
axes[0].set_ylabel('Temperature (°C)')
axes[0].grid(True)

# Nigeria Temperature Plot
axes[1].plot(nigeria_temp.index, nigeria_temp['Nigeria'], linestyle='-', color='green')
axes[1].set_title('Temperature Trend in Nigeria')
axes[1].set_ylabel('Temperature (°C)')
axes[1].grid(True)

# Formatting
plt.xlabel('Year')
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import seaborn as sns

# Combine Ghana & Nigeria data
heatmap_data = pd.concat([ghana_temp.T, nigeria_temp.T])
heatmap_data.index = ['Ghana', 'Nigeria']

# Plot heatmap
plt.figure(figsize=(12, 4))
sns.heatmap(heatmap_data, cmap='coolwarm', annot=False, linewidths=0.5, cbar=True)

plt.xlabel('Year')
plt.ylabel('Country')
plt.title('Heatmap of Temperature Trends: Ghana vs. Nigeria')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Extract temperature data
ghana_temp = df[df['Country'] == 'Ghana'].iloc[:, 4:].T
nigeria_temp = df[df['Country'] == 'Nigeria'].iloc[:, 4:].T

# Convert column names (years) to integers
ghana_temp.columns, nigeria_temp.columns = ['Ghana'], ['Nigeria']
years = ghana_temp.index.astype(int)

# Create bar width and positions
x = np.arange(len(years))
width = 0.35

# Plot bar chart
fig, ax = plt.subplots(figsize=(12, 6))
ax.bar(x - width/2, ghana_temp['Ghana'], width, label='Ghana', color='blue')
ax.bar(x + width/2, nigeria_temp['Nigeria'], width, label='Nigeria', color='green')

# Formatting
ax.set_xlabel('Year')
ax.set_ylabel('Temperature (°C)')
ax.set_title('Temperature Trends: Ghana vs. Nigeria')
ax.set_xticks(x[::5])  # Show every 5th year for readability
ax.set_xticklabels(years[::5], rotation=45)
ax.legend()
ax.grid(True, linestyle='--', alpha=0.6)

plt.show()

# %%
df.head()
# Out:
#    ID                       Country ISO3            Unit   1961   1962   1963  \
# 0   1  Afghanistan, Islamic Rep. of  AFG  Degree Celsius -0.113 -0.164  0.847
# 1   2                       Albania  ALB  Degree Celsius  0.627  0.326  0.075
# 2   3                       Algeria  DZA  Degree Celsius  0.164  0.114  0.077
# 3   4                American Samoa  ASM  Degree Celsius  0.079 -0.042  0.169
# 4   5      Andorra, Principality of  AND  Degree Celsius  0.736  0.112 -0.752
#
#     1964   1965   1966  ...   2013   2014   2015   2016   2017   2018   2019  \
# 0 -0.764 -0.244  0.226  ...  1.281  0.456  1.093  1.555  1.540  1.544  0.910
# 1 -0.166 -0.388  0.559  ...  1.333  1.198  1.569  1.464  1.121  2.028  1.675
# 2  0.250 -0.100  0.433  ...  1.192  1.690  1.121  1.757  1.512  1.210  1.115
# 3 -0.140 -0.562  0.181  ...  1.257  1.170  1.009  1.539  1.435  1.189  1.539
# 4  0.308 -0.490  0.415  ...  0.831  1.946  1.690  1.990  1.925  1.919  1.964
#
#     2020   2021   2022
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV file
data = pd.read_csv('Annual_Surface_Temperature_Change.csv')

# Define a dictionary to map African countries to sub-regions
sub_region_map = {
    'Algeria': 'North Africa', 'Angola': 'Southern Africa', 'Benin': 'West Africa',
    'Botswana': 'Southern Africa', 'Burkina Faso': 'West Africa', 'Burundi': 'East Africa',
    'Cabo Verde': 'West Africa', 'Cameroon': 'Central Africa', 'Central African Rep.': 'Central Africa',
    'Chad': 'Central Africa', 'Comoros, Union of the': 'East Africa', 'Congo, Dem. Rep. of the': 'Central Africa',
    'Congo, Rep. of the': 'Central Africa', 'Djibouti': 'East Africa', 'Egypt, Arab Rep. of': 'North Africa',
    'Equatorial Guinea, Rep. of': 'Central Africa', 'Eritrea, The State of': 'East Africa',
    'Eswatini, Kingdom of': 'Southern Africa', 'Ethiopia, The Federal Dem. Rep. of': 'East Africa',
    'Gabon': 'Central Africa', 'Gambia, The': 'West Africa', 'Ghana': 'West Africa',
    'Guinea': 'West Africa', 'Guinea-Bissau': 'West Africa', 'Ivory Coast': 'West Africa',
    'Kenya': 'East Africa', 'Lesotho, Kingdom of': 'Southern Africa', 'Liberia': 'West Africa',
    'Libya': 'North Africa', 'Madagascar, Rep. of': 'East Africa', 'Malawi': 'East Africa',
    'Mali': 'West Africa', 'Mauritania, Islamic Rep. of': 'West Africa', 'Mauritius': 'East Africa',
    'Morocco': 'North Africa', 'Mozambique, Rep. of': 'Southern Africa', 'Namibia': 'Southern Africa',
    'Niger': 'West Africa', 'Nigeria': 'West Africa', 'Rwanda': 'East Africa',
    'São Tomé and Príncipe, Dem. Rep. of': 'Central Africa', 'Senegal': 'West Africa',
    'Seychelles': 'East Africa', 'Sierra Leone': 'West Africa', 'Somalia': 'East Africa',
    'South Africa': 'Southern Africa', 'South Sudan, Rep. of': 'East Africa',
    'Sudan': 'North Africa', 'Tanzania, United Rep. of': 'East Africa',
    'Togo': 'West Africa', 'Tunisia': 'North Africa',
    'Uganda': 'East Africa', 'Zambia': 'Southern Africa',
    'Zimbabwe': 'Southern Africa'
}

# Map the countries to sub-regions
data['SubRegion'] = data['Country'].map(sub_region_map)

# Filter the data for African countries
african_data = data[data['SubRegion'].notna()]

# Filter the data for the years 1961 to 2022 and remove the "F" prefix from year columns
years = [f'F{year}' for year in range(1961, 2023)]
african_data_filtered = african_data[['SubRegion'] + years]
african_data_filtered.columns = ['SubRegion'] + [str(year) for year in range(1961, 2023)]

# Group by sub-region and calculate the mean temperature change for each year
african_data_grouped = african_data_filtered.groupby('SubRegion').mean()

# Plot small multiple plots for each sub-region
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(8, 8), sharex=True)
axes = axes.flatten()

for i, sub_region in enumerate(african_data_grouped.index):
    african_data_grouped.loc[sub_region].plot(ax=axes[i], title=sub_region)
    axes[i].set_ylabel('Temperature Change (°C)')

# Remove the last empty plot
#fig.delaxes(axes[-1])

fig.suptitle('Average Annual Surface Temperature Change in African Sub-Regions (1961-2022)', fontsize=10)
plt.xlabel('Year')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
import pandas as pd

# Load the data from the CSV file
data = pd.read_csv('Annual_Surface_Temperature_Change.csv')

# Define a dictionary to map African countries to sub-regions
sub_region_map = {
    'Algeria': 'North Africa', 'Angola': 'Southern Africa', 'Benin': 'West Africa',
    'Botswana': 'Southern Africa', 'Burkina Faso': 'West Africa', 'Burundi': 'East Africa',
    'Cabo Verde': 'West Africa', 'Cameroon': 'Central Africa', 'Central African Rep.': 'Central Africa',
    'Chad': 'Central Africa', 'Comoros, Union of the': 'East Africa', 'Congo, Dem. Rep. of the': 'Central Africa',
    'Congo, Rep. of the': 'Central Africa', 'Djibouti': 'East Africa', 'Egypt, Arab Rep. of': 'North Africa',
    'Equatorial Guinea, Rep. of': 'Central Africa', 'Eritrea, The State of': 'East Africa',
    'Eswatini, Kingdom of': 'Southern Africa', 'Ethiopia, The Federal Dem. Rep. of': 'East Africa',
    'Gabon': 'Central Africa', 'Gambia, The': 'West Africa', 'Ghana': 'West Africa',
    'Guinea': 'West Africa', 'Guinea-Bissau': 'West Africa', 'Ivory Coast': 'West Africa',
    'Kenya': 'East Africa', 'Lesotho, Kingdom of': 'Southern Africa', 'Liberia': 'West Africa',
    'Libya': 'North Africa', 'Madagascar, Rep. of': 'East Africa', 'Malawi': 'East Africa',
    'Mali': 'West Africa', 'Mauritania, Islamic Rep. of': 'West Africa', 'Mauritius': 'East Africa',
    'Morocco': 'North Africa', 'Mozambique, Rep. of': 'Southern Africa', 'Namibia': 'Southern Africa',
    'Niger': 'West Africa', 'Nigeria': 'West Africa', 'Rwanda': 'East Africa',
    'São Tomé and Príncipe, Dem. Rep. of': 'Central Africa', 'Senegal': 'West Africa',
    'Seychelles': 'East Africa', 'Sierra Leone': 'West Africa', 'Somalia': 'East Africa',
    'South Africa': 'Southern Africa', 'South Sudan, Rep. of': 'East Africa',
    'Sudan': 'North Africa', 'Tanzania, United Rep. of': 'East Africa',
    'Togo': 'West Africa', 'Tunisia': 'North Africa',
    'Uganda': 'East Africa', 'Zambia': 'Southern Africa',
    'Zimbabwe': 'Southern Africa'
}

# Map the countries to sub-regions
data['SubRegion'] = data['Country'].map(sub_region_map)

# Filter the data for African countries
african_data = data[data['SubRegion'].notna()]

# Filter the data for the years 1961 to 2022 and remove the F prefix from year columns
years = [f'F{year}' for year in range(1961, 2023)]
african_data_filtered = african_data[['SubRegion'] + years]
african_data_filtered.columns = ['SubRegion'] + [str(year) for year in range(1961, 2023)]

# Group by sub-region and calculate the mean temperature change for each year
african_data_grouped = african_data_filtered.groupby('SubRegion').mean()

# Identify the sub-region with the highest temperature change
highest_temp_sub_region = african_data_grouped.mean(axis=1).idxmax()

print("Sub-region with the highest temperature change:", highest_temp_sub_region)
# Out:
# Sub-region with the highest temperature change: West Africa

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data from the CSV file
data = pd.read_csv('Annual_Surface_Temperature_Change.csv')

# Define a dictionary to map African countries to sub-regions
sub_region_map = {
    'Algeria': 'North Africa', 'Angola': 'Southern Africa', 'Benin': 'West Africa',
    'Botswana': 'Southern Africa', 'Burkina Faso': 'West Africa', 'Burundi': 'East Africa',
    'Cabo Verde': 'West Africa', 'Cameroon': 'Central Africa', 'Central African Rep.': 'Central Africa',
    'Chad': 'Central Africa', 'Comoros, Union of the': 'East Africa', 'Congo, Dem. Rep. of the': 'Central Africa',
    'Congo, Rep. of the': 'Central Africa', 'Djibouti': 'East Africa', 'Egypt, Arab Rep. of': 'North Africa',
    'Equatorial Guinea, Rep. of': 'Central Africa', 'Eritrea, The State of': 'East Africa',
    'Eswatini, Kingdom of': 'Southern Africa', 'Ethiopia, The Federal Dem. Rep. of': 'East Africa',
    'Gabon': 'Central Africa', 'Gambia, The': 'West Africa', 'Ghana': 'West Africa',
    'Guinea': 'West Africa', 'Guinea-Bissau': 'West Africa', 'Ivory Coast': 'West Africa',
    'Kenya': 'East Africa', 'Lesotho, Kingdom of': 'Southern Africa', 'Liberia': 'West Africa',
    'Libya': 'North Africa', 'Madagascar, Rep. of': 'East Africa', 'Malawi': 'East Africa',
    'Mali': 'West Africa', 'Mauritania, Islamic Rep. of': 'West Africa', 'Mauritius': 'East Africa',
    'Morocco': 'North Africa', 'Mozambique, Rep. of': 'Southern Africa', 'Namibia': 'Southern Africa',
    'Niger': 'West Africa', 'Nigeria': 'West Africa', 'Rwanda': 'East Africa',
    'São Tomé and Príncipe, Dem. Rep. of': 'Central Africa', 'Senegal': 'West Africa',
    'Seychelles': 'East Africa', 'Sierra Leone': 'West Africa', 'Somalia': 'East Africa',
    'South Africa': 'Southern Africa', 'South Sudan, Rep. of': 'East Africa',
    'Sudan': 'North Africa', 'Tanzania, United Rep. of': 'East Africa',
    'Togo': 'West Africa', 'Tunisia': 'North Africa',
    'Uganda': 'East Africa', 'Zambia': 'Southern Africa',
    'Zimbabwe': 'Southern Africa'
}

# Map the countries to sub-regions
data['SubRegion'] = data['Country'].map(sub_region_map)

# Filter the data for African countries
african_data = data[data['SubRegion'].notna()]

# Filter the data for the years 1961 to 2022 and remove the F prefix from year columns
years = [f'F{year}' for year in range(1961, 2023)]
african_data_filtered = african_data[['SubRegion'] + years]
african_data_filtered.columns = ['SubRegion'] + [str(year) for year in range(1961, 2023)]

# Group by sub-region and calculate the mean temperature change for each year
african_data_grouped = african_data_filtered.groupby('SubRegion').mean()

# Calculate the mean temperature change for each sub-region across all years
mean_temp_change = african_data_grouped.mean(axis=1).sort_values(ascending=False)

# Create a DataFrame for plotting
plot_data = mean_temp_change.reset_index()
plot_data.columns = ['SubRegion', 'MeanTemperatureChange']

# Plot the bar chart using seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='MeanTemperatureChange', y='SubRegion', data=plot_data.head(5))
plt.title('Average Temperature Change by Sub-Region (Highest to Lowest)')
plt.xlabel('Mean Temperature Change (°C)')
plt.ylabel('Sub-Region')
plt.show()
